# %%
# !pip install pandas
# !pip install -U scikit-learn
# !pip install numpy scipy scikit-learn

# %%
# !pip install -U scikit-learn

# %%
# !pip install seaborn
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #randomised data split section

# %%
import os

# %%
import pandas as pd;

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 os.getcwd()
#
# NameError: name 'os' is not defined

# %%
df.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.sample(10)
#
# NameError: name 'df' is not defined

# %%
df.describe().T.drop(columns="count")
# Out:
#                        mean           std           min           25%  \
# id             4.580302e+09  2.876566e+09  1.000102e+06  2.123049e+09
# price          5.400881e+05  3.671272e+05  7.500000e+04  3.219500e+05
# bedrooms       3.370842e+00  9.300618e-01  0.000000e+00  3.000000e+00
# bathrooms      2.114757e+00  7.701632e-01  0.000000e+00  1.750000e+00
# sqft_living    2.079900e+03  9.184409e+02  2.900000e+02  1.427000e+03
# sqft_lot       1.510697e+04  4.142051e+04  5.200000e+02  5.040000e+03
# floors         1.494309e+00  5.399889e-01  1.000000e+00  1.000000e+00
# waterfront     7.541757e-03  8.651720e-02  0.000000e+00  0.000000e+00
# view           2.343034e-01  7.663176e-01  0.000000e+00  0.000000e+00
# condition      3.409430e+00  6.507430e-01  1.000000e+00  3.000000e+00
# grade          7.656873e+00  1.175459e+00  1.000000e+00  7.000000e+00
# sqft_above     1.788396e+03  8.281282e+02  2.900000e+02  1.190000e+03
# ...

# %%
df2= pd.read_csv(r"kc_house_data.csv",encoding='unicode_escape')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#visualising data using heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='coolwarm')
plt.show()

# %%
df.columns
# Out:
# Index(['price', 'sqft_living'], dtype='object')

# %%
df=df.drop(['id', 'date', 'bedrooms', 'bathrooms',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15'],axis=1)

# %%
df.columns
# Out:
# Index(['price', 'sqft_living'], dtype='object')

# %% [markdown]
# # feature engineering

# %%
#selection the requiredparameters
X=df['price']
Y=df['sqft_living']

# %%
#optional
X=np.array(x).reshape(-1,1)
Y=np.array(y)

# %%
X
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])

# %%
y
# Out:
# array([1180, 2570,  770, ..., 1020, 1600, 1020], dtype=int64)

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(X_test)

# %%
y_predictions = y_predict.reshape(-1,1)
y_predictions
# Out:
# array([[1747.8984747 ],
#        [1922.43876559],
#        [2245.17693466],
#        ...,
#        [1606.24258644],
#        [1892.78174465],
#        [1372.91161285]])

# %%
print(model.intercept_)
print(model.coef_)
#1sqmincrease = 280usd
# Out:
# 1137.3999759624169
# [0.00174453]

# %%
price= 1137.3999759624169 + 1000*0.00174453
price
# Out:
# 1139.1445059624168

# %%
model.predict([[1000]])
# Out:
# array([1139.14450661])

# %%
model.score ( X_test,y_test)
# Out:
# 0.5079923199932295

# %%
model.score ( X_train,y_train)
# Out:
# 0.48887806121735

# %% [markdown]
# sns.pairplot(df)

# %% [markdown]
# logistic regression

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df['cp'].unique() #integer encoding
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df['restecg'].unique() #integer encoding
# Out:
# array([1, 0, 2], dtype=int64)

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
sns.pairplot(df[['age','trestbps','chol','thalach','target']],hue='target')
# Out:
# C:\Users\sachi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScalar
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from sklearn.preprocessing import StandardScalar
#
# ImportError: cannot import name 'StandardScalar' from 'sklearn.preprocessing' (C:\Users\sachi\anaconda3\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
X=df.drop('target',axis=1)
y=df['target']

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.25,random_state=25)

# %%
scalar=StandardScalar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 scalar=StandardScalar()
#
# NameError: name 'StandardScalar' is not defined

# %%
df1=pd.read_csv('skill.csv')

# %%
df1.head()
# Out:
#             Column1         Column2          Column3              Column4  \
# 0            dot-gt        dot-gt 2         dot-gt 3             dot-gt 4
# 1      Supply chain       Economics           Pharma   Project management
# 2               SAN         tableau       Analytical  Predictive modeling
# 3    Data migration  data analytics      codeigniter                MySQL
# 4  Computer science      Analytical  Data collection            Packaging
#
#           Column5         Column6             Column7                 Column8  \
# 0        dot-gt 5        dot-gt 6            dot-gt 7                dot-gt 8
# 1      Healthcare    Data Analyst  data visualization               Analytics
# 2    Data Analyst  Data analytics         Forecasting         Reporting tools
# 3             php            Data           Analytics           Data analysis
# 4  Data analytics     Mathematics        Data Analyst  Information technology
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# ...

# %%
df1.describe()
# Out:
#        Unnamed: 8
# count         1.0
# mean       2776.0
# std           NaN
# min        2776.0
# 25%        2776.0
# 50%        2776.0
# 75%        2776.0
# max        2776.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Column1     2744 non-null   object
#  1   Column2     335 non-null    object
#  2   Column3     334 non-null    object
#  3   Column4     331 non-null    object
#  4   Column5     327 non-null    object
#  5   Column6     324 non-null    object
#  6   Column7     322 non-null    object
#  7   Column8     317 non-null    object
#  8   Unnamed: 8  1 non-null      float64
# dtypes: float64(1), object(8)
# memory usage: 193.8+ KB

# %%
df1.Column1.value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8496\3184524149.py in ?()
# ----> 1 df1.Column1.value_count()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %% [markdown]
# # CLUSTERING

# %%
#DENDROGRAM --AGLOMERATIVE AND DIVISIVE
#FINDING EUCLIAN DISTANCE ,MANHATTAN DISSTANCE
#SCALING IN CLUSTER - STANDARD SCALAR AND MIN MAX SCALAR
#STANDARD SCALAR MEAN = O AND S.D=1 FOR ALL THE COLUMMN(RECOMMENDED)
#MIN MAX RELATIVE DISTANCES REMAINS THE SAME

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.age.value_counts()
# Out:
# age
# 58    68
# 57    57
# 54    53
# 59    46
# 52    43
# 51    39
# 56    39
# 62    37
# 60    37
# 44    36
# 64    34
# 41    32
# 63    32
# 67    31
# 61    31
# 55    30
# 65    27
# 43    26
# 42    26
# 53    26
# 66    25
# 45    25
# 48    23
# 46    23
# 50    21
# 47    18
# 49    17
# 35    15
# 39    14
# 70    14
# 68    12
# 38    12
# 71    11
# 40    11
# 69     9
# 37     6
# 34     6
# 29     4
# 76     3
# 77     3
# 74     3
# Name: count, dtype: int64

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df["PHYSICAL SYMPTOMS"].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PHYSICAL SYMPTOMS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_w_dummies=pd.get_dummies(df.drop(['age'],axis=1)) #onehot  encoding

# %%
df_w_dummies
# Out:
#       sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0       1   0       125   212    0        1      168      0      1.0      2
# 1       1   0       140   203    1        0      155      1      3.1      0
# 2       1   0       145   174    0        1      125      1      2.6      0
# 3       1   0       148   203    0        1      161      0      0.0      2
# 4       0   0       138   294    1        1      106      0      1.9      1
# ...   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 1020    1   1       140   221    0        1      164      1      0.0      2
# 1021    1   0       125   258    0        0      141      1      2.8      1
# 1022    1   0       110   275    0        0      118      1      1.0      1
# 1023    0   0       110   254    0        0      159      0      0.0      2
# 1024    1   0       120   188    0        1      113      0      1.4      1
#
#       ca  thal  target
# 0      2     3       0
# ...

# %%
#min max scaling(x-xmin)/(xmax-xmin)
from sklearn.preprocessing import MinMaxScaler

# %%
Scaler=MinMaxScaler()

# %%
Scaled_data= Scaler.fit_transform(df_w_dummies)

# %%
Scaled_data
# Out:
# array([[1.        , 0.        , 0.29245283, ..., 0.5       , 1.        ,
#         0.        ],
#        [1.        , 0.        , 0.43396226, ..., 0.        , 1.        ,
#         0.        ],
#        [1.        , 0.        , 0.48113208, ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 0.1509434 , ..., 0.25      , 0.66666667,
#         0.        ],
#        [0.        , 0.        , 0.1509434 , ..., 0.        , 0.66666667,
#         1.        ],
#        [1.        , 0.        , 0.24528302, ..., 0.25      , 1.        ,
#         0.        ]])

# %%
Scaled_df=pd.DataFrame(Scaled_data,columns=df_w_dummies.columns)
Scaled_df.head()
# Out:
#    sex   cp  trestbps      chol  fbs  restecg   thalach  exang   oldpeak  \
# 0  1.0  0.0  0.292453  0.196347  0.0      0.5  0.740458    0.0  0.161290
# 1  1.0  0.0  0.433962  0.175799  1.0      0.0  0.641221    1.0  0.500000
# 2  1.0  0.0  0.481132  0.109589  0.0      0.5  0.412214    1.0  0.419355
# 3  1.0  0.0  0.509434  0.175799  0.0      0.5  0.687023    0.0  0.000000
# 4  0.0  0.0  0.415094  0.383562  1.0      0.5  0.267176    0.0  0.306452
#
#    slope    ca      thal  target
# 0    1.0  0.50  1.000000     0.0
# 1    0.0  0.00  1.000000     0.0
# 2    0.0  0.00  1.000000     0.0
# 3    1.0  0.25  1.000000     0.0
# 4    0.5  0.75  0.666667     0.0

# %%
plt.figure(figsize=(16,7))
sns.heatmap(Scaled_df,cmap='magma')
# Out:
# <Axes: >

# %%
#scikit-learn
from sklearn.cluster import AgglomerativeClustering

# %%
model_4=AgglomerativeClustering(n_clusters=4)

# %%
cluster_labels=model_4.fit_predict(Scaled_df)
cluster_labels
# Out:
# array([3, 0, 0, ..., 0, 2, 3], dtype=int64)

# %%
plt.figure(figsize=(16,7),dpi=200)
sns.scatterplot(data=df,x="thalach",y="age",hue=cluster_labels)
# Out:
# <Axes: xlabel='thalach', ylabel='age'>

# %%
len(Scaled_df.columns)
# Out:
# 13

# %%
np.sqrt(13)
# Out:
# 3.605551275463989

# %%
model= AgglomerativeClustering(n_clusters=None,distance_threshold=0)

# %%
cluster_labels=model.fit_predict(Scaled_df)
cluster_labels
# Out:
# array([1024, 1023, 1022, ...,    4,    1,    0], dtype=int64)

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy

# %%
linkage_matrix=hierarchy.linkage(model_4.children_)

# %%
plt.figure(figsize=(16,7),dpi=200)
dm=hierarchy.dendrogram(linkage_matrix)

# %%
plt.figure(figsize=(16,7),dpi=200)
dm=hierarchy.dendrogram(linkage_matrix,truncate_mode='lastp',p=20)
